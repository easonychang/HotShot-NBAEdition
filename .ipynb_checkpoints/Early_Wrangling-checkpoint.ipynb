# %% [markdown]
# # Preliminary Data Wrangling
#
# ## 1: Initializing list of dataframes for each year

# %% [markdown]
# I chose to create a list to conveniently store and access the dataframe for shot data form every year.

# %%
import pandas as pd, numpy as np, scipy as sp, matplotlib.pyplot as plt

#FG is a list that will store each year's shot data in order
FG = []
test2019 = pd.read_csv('Shot Data - CSV/Shot Data - 2018-2019.csv')

#loop through all years, adding each year's dataframe to the list
for year in range(1997,2020):
    yearint = int(year)
    yeardf = pd.read_csv('Shot Data - CSV/Shot Data - ' + str(yearint - 1) + '-' + str(yearint) + '.csv')
    FG.append(yeardf)

test2019
#now FG is a list of dataframes, length 23. Access each year in sequential order by indices 0 (1996 - 97) to 22 (2018 - 19).
# Out:
#                 Unnamed: 0 LESS THAN 8FT. Unnamed: 2 Unnamed: 3 8-16 FT.  \
# 0                     TEAM          FGM-C      FGA-C      FG%-C    FGM-M
# 1            Atlanta Hawks           1858       3275       56.7      334
# 2           Boston Celtics           1606       2687       59.8      484
# 3            Brooklyn Nets           1773       3197       55.5      349
# 4        Charlotte Hornets           1690       3081       54.9      386
# 5            Chicago Bulls           1848       3331       55.5      408
# 6      Cleveland Cavaliers           1584       2914       54.4      468
# 7         Dallas Mavericks           1626       2768       58.7      361
# 8           Denver Nuggets           1884       3288       57.3      447
# 9          Detroit Pistons           1687       3099       54.4      285
# 10   Golden State Warriors           1550       2428       63.8      511
# 11         Houston Rockets           1608       2756       58.3      207
# ...

# %% [markdown]
# ## 2: Gathering summary data across years

# %%
#lists to store the league-wide means for short, medium, and long-distance shots ATTEMPTED across years
xs_yearly_a = []
s_yearly_a = []
m_yearly_a = []
l_yearly_a = []
#MADE
xs_yearly_m = []
s_yearly_m = []
m_yearly_m = []
l_yearly_m = []
#PERCENT
xs_yearly_p = []
s_yearly_p = []
m_yearly_p = []
l_yearly_p = []

xs_mean, s_mean, m_mean, l_mean = 0,0,0,0

#list for dataframes converted to numeric values only, team names and labels removed
FG_nums = []


test2019 = test2019.iloc[1:30, 1:13]
test2019 = test2019.apply(pd.to_numeric, errors='ignore')
#print(test2019)

for df in FG:
    #convert dtype to int and float, cause it was object originally for some reason, add to list of converted dfs for future use
    #also cut off everything that wasn't int or float
    df = df.iloc[1:30, 1:13]
    df = df.apply(pd.to_numeric, errors='ignore')
    FG_nums.append(df)
    #assign the year's means for each type of shot to respective variable
    #store every mean in a list of means across the years
    xs_yearly_a.append((df.iloc[:,1:2].mean(0)).iloc[0])
    s_yearly_a.append((df.iloc[:,4:5].mean(0)).iloc[0])
    m_yearly_a.append((df.iloc[:,7:8].mean(0)).iloc[0])
    l_yearly_a.append((df.iloc[:,10:11].mean(0)).iloc[0])
    #made
    xs_yearly_m.append((df.iloc[:,0:1].mean(0)).iloc[0])
    s_yearly_m.append((df.iloc[:,3:4].mean(0)).iloc[0])
    m_yearly_m.append((df.iloc[:,6:7].mean(0)).iloc[0])
    l_yearly_m.append((df.iloc[:,9:10].mean(0)).iloc[0])
    #percent
    xs_yearly_p.append((df.iloc[:,2:3].mean(0)).iloc[0])
    s_yearly_p.append((df.iloc[:,5:6].mean(0)).iloc[0])
    m_yearly_p.append((df.iloc[:,8:9].mean(0)).iloc[0])
    l_yearly_p.append((df.iloc[:,11:12].mean(0)).iloc[0])
    
#now plot the means across time to see how average shots attempted has evolved over time
#creating x-axis...
X = []
for i in range(1997,2020):
    X.append(i)
#plotting shot data
xs_line = plt.plot(X, xs_yearly_a, c='b', label='<8ft')
s_line = plt.plot(X, s_yearly_a, c='r', label='8-16ft shots')
m_line = plt.plot(X, m_yearly_a, c='g', label='16-24ft shots')
l_line = plt.plot(X, l_yearly_a, c='y', label='24+ft shots')
plt.xlabel('Year')
plt.ylabel('Shots Attempted')
plt.title('League-Wide Mean Shots Attempted by Type')
plt.show()
#FG[0]

# %%
#plotting shot data (MADE)
xs_line = plt.plot(X, xs_yearly_m, c='b', label='<8ft')
s_line = plt.plot(X, s_yearly_m, c='r', label='8-16ft shots')
m_line = plt.plot(X, m_yearly_m, c='g', label='16-24ft shots')
l_line = plt.plot(X, l_yearly_m, c='y', label='24+ft shots')
plt.xlabel('Year')
plt.ylabel('Shots Made')
plt.title('League-Wide Mean Shots Made by Type')
plt.show()

# %%
#plotting shot data (PERCENT)
xs_line_p = plt.plot(X, xs_yearly_m, c='b', label='<8ft')
s_line_p = plt.plot(X, s_yearly_m, c='r', label='8-16ft shots')
m_line_p = plt.plot(X, m_yearly_m, c='g', label='16-24ft shots')
l_line_p = plt.plot(X, l_yearly_m, c='y', label='24+ft shots')
plt.xlabel('Year')
plt.ylabel('Shots Made')
plt.title('League-Wide Shot Percentage by Type')
plt.show()
